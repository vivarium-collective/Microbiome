# %% [markdown]
# # Flux Balance Analysis (FBA)
#
# This notebook serves as the foundation of a project aimed at predicting metabolic fluxes in biological systems. FBA involves constructing a mathematical model of the metabolic network that comprises a series of biochemical reactions converting various metabolites. Each reaction is assigned a rate or flux, representing the amount of reactants converted into products per unit time.
#
# FBA utilizes a linear programming optimization approach to determine the optimal set of flux values that meet specified constraints, including substrate availability and the production of specific metabolites. The optimization objective is to maximize or minimize a specific function, such as the organism's growth rate or the desired metabolite's production.
#
# Flux Balance Analysis (FBA) is numerical technique for simulating large metabolic networks at steady state. In this example, a flux balance model is loaded into Vivarium-Cobra from a BiGG file.

# %% [markdown]
# ## Flux Balance Analysis Process using Cobra
# A .BIG model loaded into a Vivarium-Cobra process and simulated.

# %% [markdown]
# ### BiGG File
#
# A BiGG file is a file format used in the context of systems biology to represent genome-scale metabolic models. BiGG (short for Biochemically, Genetically, and Genomically structured) is a knowledgebase of metabolic reconstructions, which are large-scale mathematical models that describe the metabolism of an organism. These models capture the biochemical reactions, genes, and metabolites involved in the metabolism.
#
# BiGG models are often saved in various file formats like SBML (Systems Biology Markup Language), JSON, or MATLAB format. These files can be used to simulate and analyze the behavior of metabolic networks, providing insights into cellular processes, metabolic engineering, and drug target identification.
#
# The BiGG database contains well-curated, standardized, and organism-specific metabolic reconstructions. It serves as a valuable resource for researchers working in systems biology, metabolic modeling, and related fields. To access BiGG models, visit the official website at http://bigg.ucsd.edu/.

# %%
# required imports
from vivarium.plots.simulation_output import _save_fig_to_dir as save_fig_to_dir
import ast
from escher import Builder
# %matplotlib inline
import matplotlib.pyplot as plt
from vivarium.plots.topology import plot_topology

# %%
# Import the FBA class and the main function from the Fba_process.py file
import sys
sys.path.append('../vivarium_microbiome/processes/Ecoli/')
from Fba import FBA, main
# Set the desired model_path
model_path = "../vivarium_microbiome/data/e_coli_core.xml"
# Call the main function with the
output, processes, topology = main(model_path)
# Out:
# Simulation ID: 60db613c-946a-11ee-922d-ba21c95c07d9
# Created: 12/06/2023 at 14:05:10
# Completed in 0.003164 seconds

# %% [markdown]
# ## Model Topology.
# #### The model compute the FBA and provide the optimized Fluxes, the Objective flux and the reactions.

# %%
composite = {'processes' : processes , 'topology' : topology , 'steps' : {}, 'flow' : {}}
config ={'font_size' : 10}
fig_topology = plot_topology(composite, config)

# %%
# extract the fluxes data
if isinstance(output, str):
    # convert the string to a dictionary
    output = ast.literal_eval(output)
flux_data = output[1]['fluxes_values']
reactions_data = output[1]['reactions_list']
objective_flux_data = output[1]['objective_flux_value']

# %%
flux_data
# Out:
# {'ACALD': 0.0,
#  'ACALDt': 0.0,
#  'ACKr': 1.0297466822596379e-15,
#  'ACONTa': 6.007249575350356,
#  'ACONTb': 6.007249575350356,
#  'ACt2r': 1.0297466822596379e-15,
#  'ADK1': 0.0,
#  'AKGDH': 5.064375661482119,
#  'AKGt2r': 0.0,
#  'ALCD2x': 0.0,
#  'ATPM': 8.39,
#  'ATPS4r': 45.51400977451756,
#  'BIOMASS_Ecoli_core_w_GAM': 0.8739215069684295,
#  'CO2t': -22.809833310205004,
#  'CS': 6.007249575350356,
#  'CYTBD': 43.598985311997616,
#  'D_LACt2': 0.0,
#  'ENO': 14.71613956874284,
#  'ETOHt2r': 0.0,
#  'EX_ac_e': 0.0,
#  'EX_acald_e': 0.0,
#  'EX_akg_e': 0.0,
#  'EX_co2_e': 22.809833310205004,
#  'EX_etoh_e': 0.0,
#  'EX_for_e': 0.0,
#  'EX_fru_e': 0.0,
#  'EX_fum_e': 0.0,
#  'EX_glc__D_e': -10.0,
#  'EX_gln__L_e': 0.0,
#  'EX_glu__L_e': 0.0,
#  'EX_h2o_e': 29.175827135565772,
#  'EX_h_e': 17.53086542978667,
#  'EX_lac__D_e': 0.0,
#  'EX_mal__L_e': 0.0,
#  'EX_nh4_e': -4.765319193197452,
#  'EX_o2_e': -21.799492655998804,
#  'EX_pi_e': -3.21489504768473,
#  'EX_pyr_e': 0.0,
#  'EX_succ_e': 0.0,
#  'FBA': 7.4773819621602895,
#  'FBP': 0.0,
#  'FORt': 0.0,
#  'FORt2': 0.0,
#  'FRD7': 0.0,
#  'FRUpts2': 0.0,
#  'FUM': 5.064375661482119,
#  'FUMt2_2': 0.0,
#  'G6PDH2r': 4.959984944574638,
#  'GAPD': 16.02352614316761,
#  'GLCpts': 10.000000000000002,
#  'GLNS': 0.2234617293318277,
#  'GLNabc': 0.0,
#  'GLUDy': -4.541857463865624,
#  'GLUN': 0.0,
#  'GLUSy': 0.0,
#  'GLUt2r': 0.0,
#  'GND': 4.959984944574632,
#  'H2Ot': -29.175827135565772,
#  'ICDHyr': 6.007249575350356,
#  'ICL': 0.0,
#  'LDH_D': -2.8851667222789664e-15,
#  'MALS': 0.0,
#  'MALt2_2': 0.0,
#  'MDH': 5.064375661482119,
#  'ME1': 0.0,
#  'ME2': 0.0,
#  'NADH16': 38.53460965051549,
#  'NADTRHD': 0.0,
#  'NH4t': 4.765319193197452,
#  'O2t': 21.799492655998804,
#  'PDH': 9.282532599166629,
#  'PFK': 7.47738196216029,
#  'PFL': 0.0,
#  'PGI': 4.860861146496837,
#  'PGK': -16.023526143167615,
#  'PGL': 4.959984944574638,
#  'PGM': -14.71613956874284,
#  'PIt2r': 3.21489504768473,
#  'PPC': 2.5043094703687303,
#  'PPCK': 0.0,
#  'PPS': 0.0,
#  'PTAr': -5.196301174036498e-15,
#  'PYK': 1.7581774441067952,
#  'PYRt2': -7.597785447006458e-16,
#  'RPE': 2.678481850507515,
#  'RPI': -2.281503094067118,
#  'SUCCt2_2': 0.0,
#  'SUCCt3': 0.0,
#  'SUCDi': 5.064375661482119,
#  'SUCOAS': -5.064375661482119,
#  'TALA': 1.4969837572615592,
#  'THD2': 0.0,
#  'TKT1': 1.496983757261559,
#  'TKT2': 1.1814980932459562,
#  'TPI': 7.4773819621602895}

# %%
# Extract exchange fluxes
exchange_fluxes = {key: value for key, value in flux_data.items() if key.startswith('EX_')}

# Sort the exchange fluxes based on their values
sorted_exchange_fluxes = sorted(exchange_fluxes.items(), key=lambda item: item[1])

# Print the sorted exchange fluxes
for key, value in sorted_exchange_fluxes:
    print(f'{key}: {value}')
# Out:
# EX_o2_e: -21.799492655998804
# EX_glc__D_e: -10.0
# EX_nh4_e: -4.765319193197452
# EX_pi_e: -3.21489504768473
# EX_ac_e: 0.0
# EX_acald_e: 0.0
# EX_akg_e: 0.0
# EX_etoh_e: 0.0
# EX_for_e: 0.0
# EX_fru_e: 0.0
# EX_fum_e: 0.0
# EX_gln__L_e: 0.0
# EX_glu__L_e: 0.0
# EX_lac__D_e: 0.0
# EX_mal__L_e: 0.0
# EX_pyr_e: 0.0
# EX_succ_e: 0.0
# EX_h_e: 17.53086542978667
# EX_co2_e: 22.809833310205004
# EX_h2o_e: 29.175827135565772

# %%
uptake_fluxes = {key: value for key, value in exchange_fluxes.items() if value < 0}
secretion_fluxes = {key: value for key, value in exchange_fluxes.items() if value > 0}

# Print uptake fluxes
print("Uptake Fluxes:")
for key, value in uptake_fluxes.items():
    print(f'{key}: {value}')

# Print secretion fluxes
print("\nSecretion Fluxes:")
for key, value in secretion_fluxes.items():
    print(f'{key}: {value}')
# Out:
# Uptake Fluxes:
# EX_glc__D_e: -10.0
# EX_nh4_e: -4.765319193197452
# EX_o2_e: -21.799492655998804
# EX_pi_e: -3.21489504768473
#
# Secretion Fluxes:
# EX_co2_e: 22.809833310205004
# EX_h2o_e: 29.175827135565772
# EX_h_e: 17.53086542978667

# %%
# Separating keys and values for plotting
fluxes_keys = [key for key, _ in sorted_exchange_fluxes]
fluxes_values = [value for _, value in sorted_exchange_fluxes]

# Creating the bar chart
plt.figure(figsize=(10, 6))
plt.bar(fluxes_keys, fluxes_values, color='blue')

plt.xlabel('Exchange Fluxes')
plt.ylabel('Flux Value')
plt.title('Exchange Fluxes Visualization')
plt.xticks(rotation=90)  # Rotate labels to avoid overlap
plt.tight_layout()  # Adjusts the plot to ensure everything fits without overlapping

plt.show()

# %%
#Escher
# Load the E. coli core map
builder = Builder(
    map_name="e_coli_core.Core metabolism",     #user should choose it. 
    reaction_data=flux_data,
    show_gene_reaction_rules=False,
)

# Save the Escher plot as an HTML file
builder.save_html("../Plots/escher_plot.html")

# To display the Escher plot in Jupyter Notebook, return the builder object
builder

# %%
from IPython.display import display, HTML
with open("../Plots/escher_plot.html", "r") as file:
    html_content = file.read()

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <title>Escher Builder</title>
#
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.2.0/jquery.min.js"></script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.6/js/bootstrap.min.js"></script>
#
#
#
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootswatch/3.3.6/simplex/bootstrap.min.css"/>
#
#
#     <link rel="stylesheet" href="https://unpkg.com/escher-vis@1.6.0/css/dist/builder.min.css"/>
#
#
#
#
#       <link rel="shortcut icon" href="https://escher.github.io/escher/static/img/favicon.ico" />
#
#
#     <meta charset="utf-8"/>
#     <meta name="viewport" content="width=device-width, height=device-height,
#                                    initial-scale=1.0, maximum-scale=1.0, user-scalable=no, minimal-ui"/>
#   </head>
#   <body>
#
#   <div style="height: 100%; width: 100%;" id="gontqkytyx"></div>
#
#   <script>
#    /* Closure to make sure data only applies to this map. */
#    (function() {
#        /* data from python */
#        var data = get_data();
#
#        function load_lib(url, callback) {
#            /** Dynamically load a JavaScript file */
#            var s = document.createElement('script');
#            s.src = url;
#            s.async = true;
#            s.onreadystatechange = s.onload = callback;
#            s.onerror = function() {
#                console.warn('Failed to load library ' + url);
#            };
#            document.getElementsByTagName('head')[0].appendChild(s);
#        }
#
#        function check_global_and_load(name, url, callback) {
#            /** Look for the name in the global scope. If it isn't present, then
#               load the library at url. Returns the object. */
#            if (window[name] !== undefined) {
#                callback(window[name]);
#            } else {
#                load_lib(url, function() {
#                    callback(window[name]);
#                });
#            }
#        }
#
#        function draw_escher(escher) {
#            /** Get data and draw */
#            var load = function(t_map_data, t_model_data, t_options) {
#                escher.Builder(t_map_data, t_model_data, data.builder_embed_css,
#                               escher.libs.d3_select('#' + data.id), t_options);
#            }
#
#            // for the static site, use the url attributes for the map and model
#            // information
#            if (data.static_site_index !== null) {
#                escher.static.load_map_model_from_url(data.map_download_url, data.model_download_url,
#                                                      data.static_site_index, data.options, load);
#            } else {
#                load(data.map_data, data.model_data, data.options);
#            }
#        }
#
#        // Load dependencies and draw
#        if (typeof define === 'function' && define.amd) {
#            // require.js is available: use it to load escher
#            require.config({
#              paths: {
#                escher: 'https://unpkg.com/escher-vis@1.6.0/js/dist/escher.min',
#              },
#              // Override urlArgs that adds ?v= to the end of the escher URL and
#              // messes up unpkg links. Honestly, I'm not sure if this will lead
#              // to downstream bugs in the notebook, but they really shouldn't be
#              // doing this cache-busting anyway.
#              urlArgs: null,
#            })
#            require([ 'escher' ], function(escher) {
#                draw_escher(escher);
#            })
#        } else {
#            // require.js not available: dynamically load escher
#            check_global_and_load('escher', 'https://unpkg.com/escher-vis@1.6.0/js/dist/escher.min.js', function(escher) {
#                draw_escher(escher);
#            })
#        }
#
#        // Put this at the end so Chrome doesn't cut off the code above.
#        function get_data() {
#            /** Return the data passed in by the Python module. */
#            return {
#                id: JSON.parse('"gontqkytyx"'),
#                map_download_url: JSON.parse('"https://escher.github.io/1-0-0/5/maps/"'),
#                model_download_url: JSON.parse('"https://escher.github.io/1-0-0/5/models/"'),
#                options: JSON.parse('{"menu": "all", "enable_keys": true, "enable_editing": true, "scroll_behavior": "pan", "fill_screen": true, "ignore_bootstrap": false, "never_ask_before_quit": false, "reaction_data": {"ACALD": 0.0, "ACALDt": 0.0, "ACKr": 1.0297466822596379e-15, "ACONTa": 6.007249575350356, "ACONTb": 6.007249575350356, "ACt2r": 1.0297466822596379e-15, "ADK1": 0.0, "AKGDH": 5.064375661482119, "AKGt2r": 0.0, "ALCD2x": 0.0, "ATPM": 8.39, "ATPS4r": 45.51400977451756, "BIOMASS_Ecoli_core_w_GAM": 0.8739215069684295, "CO2t": -22.809833310205004, "CS": 6.007249575350356, "CYTBD": 43.598985311997616, "D_LACt2": 0.0, "ENO": 14.71613956874284, "ETOHt2r": 0.0, "EX_ac_e": 0.0, "EX_acald_e": 0.0, "EX_akg_e": 0.0, "EX_co2_e": 22.809833310205004, "EX_etoh_e": 0.0, "EX_for_e": 0.0, "EX_fru_e": 0.0, "EX_fum_e": 0.0, "EX_glc__D_e": -10.0, "EX_gln__L_e": 0.0, "EX_glu__L_e": 0.0, "EX_h2o_e": 29.175827135565772, "EX_h_e": 17.53086542978667, "EX_lac__D_e": 0.0, "EX_mal__L_e": 0.0, "EX_nh4_e": -4.765319193197452, "EX_o2_e": -21.799492655998804, "EX_pi_e": -3.21489504768473, "EX_pyr_e": 0.0, "EX_succ_e": 0.0, "FBA": 7.4773819621602895, "FBP": 0.0, "FORt": 0.0, "FORt2": 0.0, "FRD7": 0.0, "FRUpts2": 0.0, "FUM": 5.064375661482119, "FUMt2_2": 0.0, "G6PDH2r": 4.959984944574638, "GAPD": 16.02352614316761, "GLCpts": 10.000000000000002, "GLNS": 0.2234617293318277, "GLNabc": 0.0, "GLUDy": -4.541857463865624, "GLUN": 0.0, "GLUSy": 0.0, "GLUt2r": 0.0, "GND": 4.959984944574632, "H2Ot": -29.175827135565772, "ICDHyr": 6.007249575350356, "ICL": 0.0, "LDH_D": -2.8851667222789664e-15, "MALS": 0.0, "MALt2_2": 0.0, "MDH": 5.064375661482119, "ME1": 0.0, "ME2": 0.0, "NADH16": 38.53460965051549, "NADTRHD": 0.0, "NH4t": 4.765319193197452, "O2t": 21.799492655998804, "PDH": 9.282532599166629, "PFK": 7.47738196216029, "PFL": 0.0, "PGI": 4.860861146496837, "PGK": -16.023526143167615, "PGL": 4.959984944574638, "PGM": -14.71613956874284, "PIt2r": 3.21489504768473, "PPC": 2.5043094703687303, "PPCK": 0.0, "PPS": 0.0, "PTAr": -5.196301174036498e-15, "PYK": 1.7581774441067952, "PYRt2": -7.597785447006458e-16, "RPE": 2.678481850507515, "RPI": -2.281503094067118, "SUCCt2_2": 0.0, "SUCCt3": 0.0, "SUCDi": 5.064375661482119, "SUCOAS": -5.064375661482119, "TALA": 1.4969837572615592, "THD2": 0.0, "TKT1": 1.496983757261559, "TKT2": 1.1814980932459562, "TPI": 7.4773819621602895}, "metabolite_data": null, "gene_data": null, "show_gene_reaction_rules": false}'),
#                builder_embed_css: JSON.parse('null'),
#                map_data: JSON.parse('[{"map_name": "e_coli_core.Core metabolism", "map_id": "0df3827fde8464e80f455a773a52c274", "map_description": "E. coli core metabolic network\\nLast Modified Fri Dec 05 2014 16:39:44 GMT-0800 (PST)", "homepage": "https://escher.github.io", "schema": "https://escher.github.io/escher/jsonschema/1-0-0#"}, {"reactions": {"1577514": {"name": "Formate transport in via proton symport", "bigg_id": "FORt2", "segments": {"11": {"to_node_id": "1577044", "from_node_id": "1576666", "b2": {"y": 4749.209372712298, "x": 1360.0}, "b1": {"y": 4827.353507999329, "x": 1360.0}}, "10": {"to_node_id": "1577046", "from_node_id": "1577045", "b2": null, "b1": null}, "13": {"to_node_id": "1576590", "from_node_id": "1577046", "b2": {"y": 4275.94781629675, "x": 1360.0}, "b1": {"y": 4411.784344889025, "x": 1360.0}}, "12": {"to_node_id": "1577044", "from_node_id": "1576833", "b2": {"y": 4744.773286702694, "x": 1360.0}, "b1": {"y": 4779.244289008981, "x": 1360.0}}, "14": {"to_node_id": "1576811", "from_node_id": "1577046", "b2": {"y": 4422.5658350974745, "x": 1360.0}, "b1": {"y": 4455.769750529243, "x": 1360.0}}, "9": {"to_node_id": "1577045", "from_node_id": "1577044", "b2": null, "b1": null}}, "genes": [{"bigg_id": "b2492", "name": "focB"}, {"bigg_id": "b0904", "name": "focA"}], "reversibility": false
